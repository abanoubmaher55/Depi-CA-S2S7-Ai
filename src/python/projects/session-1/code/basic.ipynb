# %%
print("hello")
# Out:
# hello

# %%
print ("hello Abanoub")
# Out:
# hello Abanoub

# %%
age=21
print("my name is Abanoub and my age is",age)
# Out:
# my name is Abanoub and my age is 21

# %%
x=10
hex(id(x))
# Out:
# '0x7fffde994ad8'

# %%
abs(-8)
# Out:
# 8

# %%
x=88  #this variable is int
'''
dhfjjdjjjjjjjjjjjjjjjsks
'''
# Out:
# '\ndhfjjdjjjjjjjjjjjjjjjsks\n'

# %%
from basic

# %%
x=10
print(type(x))
y="Abanoub"
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
name="Abanoub"
age=21
print("My name is {0} and my is {1} ".format(name,age))
# Out:
# My name is Abanoub and my is 21

# %%
name="Abanoub Maher"
age=21
course="Ai and ML"
print("My name is {0}, and I am {1} years old I am engaged in learning {2}".format(name,age,course))
# Out:
# My name is Abanoub Maher, and I am 21 years old I am engaged in learning Ai and ML

# %%
name="Abanoub Maher"
age=21
course="Ai and ML"
output=f"My name is {name}, and I am {age} years old I am engaged in learning {course}"
print(output)
# Out:
# My name is Abanoub Maher, and I am 21 years old I am engaged in learning Ai and ML

# %%
x=[1,2,3,4,5,"hi",[22,3,33]]
x[0]=9
print(x)
print(type(x))
print(x[2])
# Out:
# [9, 2, 3, 4, 5, 'hi', [22, 3, 33]]
# <class 'list'>
# 3

# %%
name="depi for everyone"
print(len(name))
print(name[len(name)-1])
print(name[5:8:1])
# Out:
# 17
# e
# for

# %%
name="depi for machine learning"
print(name.upper())
print(name.lower())
print(name.replace("machine","deep"))
print(name.capitalize())
print(name.title())
print(name.count("depi"))
x=name.split()
print(x)
y=' '.join(x)
print(y)
# Out:
# DEPI FOR MACHINE LEARNING
# depi for machine learning
# depi for deep learning
# Depi for machine learning
# Depi For Machine Learning
# 1
# ['depi', 'for', 'machine', 'learning']
# depi for machine learning
