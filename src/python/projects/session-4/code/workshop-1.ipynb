# %%
def is_prime(num:int)->bool:
    '''
    this function to return the number is prime or not
    Args:
       num(int):number of the input user
    Returns:
       bool:number is prime or not
    '''
    for i in range (2,num):
        if num%2==0:
            return False
        else:
            return True

# %%
x=int(input("enter your numbers"))
is_prime(x)
# Out:
# True

# %%
def fact(num:int)->int:
    '''
    this function to return factorial number
    Args:
        num(int):number of the input user
    Returns:
        int:number of factorial    


    '''
    if num==0:
        return 1
    else:
        return num*fact(num-1)

# %%
fact(5)
# Out:
# 120

# %%
def common_divisors(num1:int,num2:int)->list[int]:
    limit = min(num1,num2)
    devisor= []
    for i in range(1,limit+1):
        if num1%i==0 and num1%i==0:
            devisor.append(i)
    return devisor

# %%
common_divisors(10,20)
# Out:
# [1, 2, 5, 10]

# %%
s="Hello world"
lst=s.split()
new_lst=lst[::-1]
new_lst=' '.join(new_lst)
print(new_lst)
# Out:
# world Hello

# %%
def reverse(text:str)->list:
    text=text.split()
    new_list=text[::-1]
    new_list=' '.join(new_list)
    return new_list
text=("hello world")
reverse(text)
# Out:
# 'world hello'

# %%
import random
characters="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
password=""
for _ in range(8):
    password += random.choice(characters)
print(password)
# Out:
# de3eYW&D

# %%
def generate_password(lenth: int)->str:
    import random
    char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password = ""
    for _ in range (lenth):
        password +=random.choice(char)
    return  password

# %%
generate_password(6)
# Out:
# '^D$Nse'

# %%
import string
character=(
    string.ascii_letters+string.digits+string.punctuation
)
character
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import string
import secrets
def generate_pass(length:int)->str:
    '''
    this function to generate password
    Args:
        length(int):length of the password to user
    Returns:
        str:return the password    
    '''
    if length<=0:
        raise ValueError("password length must be greater than zero")
    character=(
    string.ascii_letters+string.digits+string.punctuation)


    return "".join(secrets.choice(character)for _ in range (length))

# %%
generate_pass(5)
# Out:
# '(lcGV'

# %%
number=[1,2,3,4,5]
squres=[]
for num in number:
    squres.append(num**2)
squres
# Out:
# [1, 4, 9, 16, 25]

# %%
squres=[num**2 for num in number if num%2==0]
squres
# Out:
# [4, 16]

# %%
words = ["welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]

word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1
print(word_count)
# Out:
# {'welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %%
words = ["welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words=set(words)
count={word :0 for word in unique_words}
for i in unique_words:
    for j in words:
        if i==j:
            count[i]+=1
count
# Out:
# {'Ali': 4, 'No': 3, 'Hi': 2, 'welcome': 1}

# %%
def count_words(words):
    word_count = {}

    for word in words:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1

    return word_count
words = ["welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
result = count_words(words)

print(result)
# Out:
# {'welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %%
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}

import random
def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])
 
def main_1():
    print("chatbot : hi how i can help you!")
    while True:
        user_input = input("User:  ").lower()
        response = get_response(user_input)
        print("chatbot ", response)
       
        if user_input == "goodbye":
            break
main()
# Out:
# chatbot : hi how i can help you!
# chatbot  I'm sorry, I didn't understand.
# chatbot  Hi there!
# chatbot  Hello!
# chatbot  Could you please rephrase that?
# chatbot  I'm sorry, I didn't understand.
# chatbot  Could you please rephrase that?

# %%
num1=int(input("enter number 1"))
num2=int(input("enter number 2"))
print(num1/num2)
# Out:
# 4.0

# %%
try :
    5/0
except ZeroDivisionError:
    print("division by zero not allowed")
# Out:
# division by zero not allowed
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
