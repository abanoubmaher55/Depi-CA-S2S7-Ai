# %%
list_one=[1,2,3,4,"Depi","learning",True,[1,2,3,"True",["ML","DL","GenAI"]]]
list_one[5]="machine learning"
print(list_one)
print(list_one[7][4][1])
# Out:
# [1, 2, 3, 4, 'Depi', 'machine learning', True, [1, 2, 3, 'True', ['ML', 'DL', 'GenAI']]]
# DL

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list_1=["depi","ML","python"]
list_1.append("DL")
print(list_1)
# Out:
# ['depi', 'ML', 'python', 'DL']

# %%
list_1=["depi","ML","python"]
list_1.insert(1,"DL")
print(list_1)
# Out:
# ['depi', 'DL', 'ML', 'python']

# %%
list_1=["depi","DL","python"]
list_2=["DL","Data engineer","big data"]
list_3= list_1 + list_2
print(list_1)
print(list_3)
# Out:
# ['depi', 'DL', 'python']
# ['depi', 'DL', 'python', 'DL', 'Data engineer', 'big data']

# %%
list_1=["depi","DL","python"]
list_2=["DL","Data engineer","big data"]
list_1.extend(list_2)
print(list_1)
# Out:
# ['depi', 'DL', 'python', 'DL', 'Data engineer', 'big data']

# %%
list_1=["depi","ML","python","depi"]
x=list_1.pop()
print(list_1)
print(x)
print(type(x))
# Out:
# ['depi', 'ML', 'python']
# depi
# <class 'str'>

# %%
input_list=["amit","learning","amit","python","ML","DS","DL"]
element=input("please enter word to remove")
input_list.remove(element)
print("output list = ",input_list)
print("element remove",element)
# Out:
# output list =  ['learning', 'amit', 'python', 'ML', 'DS', 'DL']
# element remove amit

# %%
list_1=["depi","ML","python"]
list_2=["DL","AI","Data"]
x=list_1.pop()
list_2.append(x)
print(list_1)
print(list_2)
# Out:
# ['depi', 'ML']
# ['DL', 'AI', 'Data', 'python']

# %%
list_1=["depi","ML","python","DL","AI","Data"]
del list_1[1:3]
print(list_1)
# Out:
# ['depi', 'DL', 'AI', 'Data']

# %%
list_1=["depi","ML","python","DL","AI","Data"]
list_1.clear()
print(list_1)
# Out:
# []

# %%
list_1=[1,5,7,9,11,100,256,444]
new_list=list_1.count(100)
new_list
# Out:
# 1

# %%
list_1=[1,5,7,9,11,100,256,444]
new_list=list_1.index(100)
new_list
# Out:
# 5

# %%
list_2=[100,5,1,900,620]
list_2.sort()
list_2
# Out:
# [1, 5, 100, 620, 900]

# %%
list_2=[1,5,900,7,9,844,11,100,256,444]
x=sorted(list_2)
print(x)
print(list_2)
# Out:
# [1, 5, 7, 9, 11, 100, 256, 444, 844, 900]
# [1, 5, 900, 7, 9, 844, 11, 100, 256, 444]

# %%
list_2=[1,5,900,7,9,844,11,100,256,444]
list_2.reverse()
print(list_2)
# Out:
# [444, 256, 100, 11, 844, 9, 7, 900, 5, 1]

# %%
tup=("depi","ML","python","DL","AI","Data")
print(type(tup))
print(tup[2])
new_tup=list(tup)
new_tup.append("CV")
print(new_tup)
print(type(new_tup))
# Out:
# <class 'tuple'>
# python
# ['depi', 'ML', 'python', 'DL', 'AI', 'Data', 'CV']
# <class 'list'>

# %%
set1={"depi","Learning","depi"}
print(type(set1))
print(set1)
# Out:
# <class 'set'>
# {'Learning', 'depi'}

# %%
list=["depi","ML","python","DL","AI","Data","depi","ML","python","DL"]
x=set(list)
print(set(list))
print(type(list))
print(type(x))
print(x)
list[0]
# Out:
# {'DL', 'depi', 'AI', 'python', 'Data', 'ML'}
# <class 'list'>
# <class 'set'>
# {'DL', 'depi', 'AI', 'python', 'Data', 'ML'}
# 'depi'

# %%
data1={101,102,103,104}
data2={103,104,105,106}
print(data1.intersection(data2))
print(data1.union(data2))
# Out:
# {104, 103}
# {101, 102, 103, 104, 105, 106}

# %%
dict1={"k1":10,"k2":20,"k3":30}
dict1["k2"]="ML"
print(dict1)
print(type(dict1))
# Out:
# {'k1': 10, 'k2': 'ML', 'k3': 30}
# <class 'dict'>

# %%
list=[('a',10),('b',20),('c',30)]
new_list=dict(list)
print(type(new_list))
print(new_list)
# Out:
# <class 'dict'>
# {'a': 10, 'b': 20, 'c': 30}

# %%
chatbot={"hello":"hello! how can help me",
         "python":"python is a programming language",
         "ai":"enable machine to work with data"}
print(chatbot.keys())
print(chatbot.items())
print(chatbot.values())
# Out:
# dict_keys(['hello', 'python', 'ai'])
# dict_items([('hello', 'hello! how can help me'), ('python', 'python is a programming language'), ('ai', 'enable machine to work with data')])
# dict_values(['hello! how can help me', 'python is a programming language', 'enable machine to work with data'])

# %%
chatbot={"hello":"hello! how can help me",
         "python":"python is a programming language",
         "ai":"enable machine to work with data"}
question=input("Question: ")
print(chatbot.get(question,"not found"))
# Out:
# python is a programming language

# %%
num1=float(input("enter number 1"))
num2=float(input("enter number 2"))
print(f"{num1}+{num2} = ",num1+num2)
print(f"{num1}-{num2} = ",num1-num2)
print(f"{num1}*{num2} = ",num1*num2)
print(f"{num1}/{num2} = ",num1/num2)
# Out:
# 5.0+2.0 =  7.0
# 5.0-2.0 =  3.0
# 5.0*2.0 =  10.0
# 5.0/2.0 =  2.5

# %%
score=float(input("enter your score : "))
if 0<=score<=100:
    if 90<=score <=100:
        grade='A'
    elif 80<=score <90:
        grade='B'
    elif 70<=score <80:
        grade='C'  
    elif 60<=score <70:
        grade='D' 
    else :
        grade='F' 
    print(f"the student is grade is {grade}")          
else:
    print("enter youe score between 0 to 100 ")
# Out:
# the student is grade is F
