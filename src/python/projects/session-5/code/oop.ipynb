# %%
class Student:
    """ class info """
    name="Depi"
    age=5
    def std_info(self): 
      print (self)

# %%
s1=Student()
s1.name="Abanoub"
s1.age=21
print(s1.name)
print(s1.age)
print(s1.std_info())

s2=Student()
s2.name="Maher"
s2.age=40
print(s2.name)
print(s2.age)
print(s2.std_info())
# Out:
# Abanoub
# 21
# ...
# None
# Maher
# 40
# ...
# None

# %%
class Student:
    def __init__(self,name="test",age=00)->None:
        self.name=name
        self.age=age
        self.grade=0
    def std_info(self):
        return f"My name is {self.name} and my age is {self.age}"

# %%
s1=Student("Abanoub",21)
s1.std_info()
# Out:
# 'My name is Abanoub and my age is 21'

# %%
class Calc:
    def __init__(self,x=0,y=0):
        self.x=x
        self.y=y
    def add(self):
        return f"{self.x} + {self.y} = {self.x+self.y}"

# %%
c1=Calc(10,5)
c1.add()
# Out:
# '10 + 5 = 15'

# %%
from abc import ABC,abstractmethod
class Animal(ABC):
    @abstractmethod
    def move(self):
        pass

class Bird(Animal):
    def move(self):
        print("move from Bird") 

class Cat(Animal):
    def move(self):
        print("move from Cat")

a=Bird()
a.move()
# Out:
# move from Bird

# %%
class Rectangle:
    _length=10
    width=5

    def area(self):
        return self._length * self.width
r=Rectangle()
print(r._length) 
print(r.width)   
print(r.area())
# Out:
# 10
# 5
# 50

# %%
class Rectangle:
   def __init__(self,length,width):
        self.__length=length
        self.width=width
   @property
   def length(self):
        return self.__length 

   @length.setter
   def length(self,value):
       if value<=0:
           raise ValueError("length must be positive")
       self.__length=value
r=Rectangle(10,20)
r.length
# Out:
# 10

# %%
class Parent:
    def __init__(self) -> None:
        self.__value = 10


class Child(Parent):
    def __init__(self) -> None:
        super().__init__()
        self.__value = 20


c = Child()
print(c.__dict__)
# Out:
# {'_Parent__value': 10, '_Child__value': 20}

# %%
class Shape:
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius

    def calculate_area(self):
        return 3.14*(self.radius)**2


class Squar(Shape):
    def __init__(self,side):
        self.side=side
        
    def calculate_area(self):
         return self.side**2

c= Circle(5)
s= Squar(4)
print("Area from Circle =",c.calculate_area())  
print("Area from Squar =",s.calculate_area())
# Out:
# Area from Circle = 78.5
# Area from Squar = 16

# %%
#dock type
class dog:
    def speak(self):
        return "Woof"
class cat:   
    def speak(self):
            return "Meow"

d1=dog()
c1=cat()

def make_sound(animal):
    return animal.speak()
print(make_sound(dog()))
print(make_sound(cat()))
# Out:
# Woof
# Meow

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def __str__(self):
        return f"my name is {self.name} and my age is {self.age}"
    def __repr__(self)->str:
        return f"my name is {self.name} and my age is {self.age}"

# %%
class Model:
    def fit(self,x,y):
        raise NotImplementedError
    
    def predict(self,x):
            raise NotImplementedError
    
class LinearRegression(Model):
    def fit(self,x,y):
        print("fitting Linear Regression")

    def predict(self,x):
        print("predictinf with Linear Regression")

class DicisionTree(Model):
    def fit(self,x,y):
        print("fitting Decision Tree ")
        
    def predict(self,x):
        print("predicting with Decision Tree ")

models=[LinearRegression(),DicisionTree()]
for model in models:
    model.fit(None,None)
    model.predict(None)
# Out:
# fitting Linear Regression
# predictinf with Linear Regression
# fitting Decision Tree
# predicting with Decision Tree
