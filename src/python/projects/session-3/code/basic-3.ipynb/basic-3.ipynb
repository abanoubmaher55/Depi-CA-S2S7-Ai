# %%
for i in range(6):
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x=6
while x>=0:
    print(x)
    x-=1
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
x=6
while x>0:
    print("python")
    x-=2
# Out:
# python
# python
# python

# %%
def info_user(age,name="test")->str:
    '''
    this function to return the name and age of the user
    Args:
        name(str): name of the user
        age(int): age of the user
    Returns:
        str:name and age of the user    
    '''


    return f"my name is {name} and my age is {age}"

# %%
info_user(age=21)
# Out:
# 'my name is Abanoub and mu age is 21'

# %%
def info_user(name :str| None ="Abanoub",age=21 ):
    '''
     this function to return the name and age of the user
    Args:
        name(str): name of the user
        age(int): age of the user
    Returns:
        str : name and age of the user
    '''
    return f"my name is {name} and mu age is {age}"

# %%
info_user(21,21)
# Out:
# 'my name is 21 and mu age is 21'

# %%
name=input("please inter your name")
age=input("please inter your age")
info_user(name,age)
# Out:
# 'my name is bob and mu age is 21'

# %%
def fun_1(*name):
    print(name)
    print(type(name))

fun_1("depi","depi","amit",21)
# Out:
# {'depi': 'r5', 'depi2': 'r5'}
# <class 'dict'>

# %%
def fun(*names):
    print(names)
names=input("enter your names").split()
print(fun(*names))
# Out:
# ('Abanoub', 'Maher', 'Awad')
# None

# %%
def fun(**info):
    print(info)
name=input("enter your name : ")
age=input("enter your age : ")
fun(name=name,age=age)
# Out:
# {'name': 'Abanoub', 'age': '21'}

# %%
def train_model(model_name, *datasets, **hyperparameters):
    print(f"Training Model: {model_name}")

    print("\nDatasets\n")
    for dataset in datasets:
        print("-", dataset)

    print("\nHyperparameters\n")
    for key, value in hyperparameters.items():
        print(f"{key}: {value}")

# %%
train_model(
    "Fraud Detection",
    "train.csv",
    "validation.csv",
    "test.csv",
    learning_rate=0.001,
    epochs=100,
    batch_size=64,
    optimizer="Adam",
    early_stopping=True
)
# Out:
# Training Model: Fraud Detection
#
# Datasets
#
# - train.csv
# - validation.csv
# - test.csv
#
# Hyperparameters
#
# learning_rate: 0.001
# epochs: 100
# batch_size: 64
# optimizer: Adam
# early_stopping: True

# %%
def sum(x):
    return x+10
sum(10)
# Out:
# 20

# %%
sum_1 =lambda x:x+10
sum_1(10)
# Out:
# 20

# %%
def fun_2(x):
    return lambda y:x+y
x=fun_2(5)
x(10)
# Out:
# 15

# %%
transformers = {
    "lower": lambda text: text.lower(),
    "upper": lambda text: text.upper(),
    "strip": lambda text: text.strip(),
    "title": lambda text: text.title(),
    "reverse": lambda text: text[::-1],
    "word_count": lambda text: len(text.split()),
    "char_count": lambda text: len(text),
    "remove_spaces": lambda text: text.replace(" ", "")
}

# %%
text="Machine Learning With Python"
print(transformers["strip"](text))
print(transformers["lower"](text))
# Out:
# Machine Learning With Python
# machine learning with python
